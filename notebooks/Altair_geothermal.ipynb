# %% [markdown]
# plt.semilogx(dgs_stats['grain size bins'], dgs_stats['grain size frequencies'], 'k-o', label='GSD')

# %%
plt.semilogx(dgs_stats['grain size bins'], dgs_stats['grain size frequencies'], 'k-o', label='GSD')

# %%
import altair as alt
from vega_datasets import data

# for the notebook only (not for JupyterLab) run this command once per session
alt.renderers.enable('notebook')

iris = data.iris()

alt.Chart(iris).mark_point().encode(
    x='petalLength',
    y='petalWidth',
    color='species'
)

# %%
import pandas as pd

# %%
dat = pd.read_csv('Geothermal_power.csv')

# %%
dat
# Out:
#              Country Geographical Region  Capacity (MW) 2007  \
# 0                USA       North America              2687.0
# 1        Philippines                Asia              1969.7
# 2          Indonesia                Asia               992.0
# 3             Mexico     Central America               953.0
# 4        New Zealand             Oceania               471.6
# 5              Italy              Europe               810.5
# 6            Iceland              Europe               421.2
# 7              Kenya              Africa               128.8
# 8              Japan                Asia               535.2
# 9             Turkey              Europe                38.0
# 10        Costa Rica     Central America               162.5
# 11       El Salvador     Central America               204.4
# 12         Nicaragua     Central America                79.0
# 13  Papua New Guinea             Oceania                56.0
# 14         Guatemala     Central America                53.0
# 15          Portugal              Europe                23.0
# 16            Russia              Europe                79.0
# 17             China                Asia                27.8
# 18           Germany              Europe                 8.4
# 19            France              Europe                14.7
# 20          Ethiopia              Africa                 7.3
# 21           Austria              Europe                 1.1
# 22         Australia             Oceania                 0.2
# 23          Thailand                Asia                 0.3
#
#     Capacity (MW) 2010  Capacity (MW) 2013  Capacity (MW) 2015  \
# 0               3086.0              3389.0              3450.0
# 1               1904.0              1894.0              1870.0
# 2               1197.0              1333.0              1340.0
# 3                958.0               980.0              1017.0
# 4                628.0               895.0              1005.0
# 5                843.0               901.0               916.0
# 6                575.0               664.0               665.0
# 7                167.0               215.0               594.0
# 8                536.0               537.0               519.0
# 9                 82.0               163.0               397.0
# 10               166.0               208.0               207.0
# 11               204.0               204.0               204.0
# 12                82.0                97.0                82.0
# 13                56.0                56.0                50.0
# 14                52.0                42.0                52.0
# 15                29.0                28.0                29.0
# 16                79.0                82.0                82.0
# 17                24.0                27.0                27.0
# 18                 6.6                13.0                27.0
# 19                16.0                15.0                16.0
# 20                 7.3                 8.0                 7.3
# 21                 1.4                 1.0                 1.2
# 22                 1.1                 1.0                 1.1
# 23                 0.3                 0.3                 0.3
#
#     Capacity (MW) 2018  Share of national generation (%)
# 0               3591.0                               0.3
# 1               1868.0                              27.0
# 2               1948.0                               3.7
# 3                951.0                               3.0
# 4               1005.0                              14.5
# 5                944.0                               1.5
# 6                755.0                              30.0
# 7                676.0                              51.0
# 8                542.0                               0.1
# 9               1200.0                               0.3
# 10                 NaN                              14.0
# 11                 NaN                              25.0
# 12                 NaN                               9.9
# 13                 NaN                               NaN
# 14                 NaN                               NaN
# 15                 NaN                               NaN
# 16                 NaN                               NaN
# 17                 NaN                               NaN
# 18                 NaN                               NaN
# 19                 NaN                               NaN
# 20                 NaN                               NaN
# 21                 NaN                               NaN
# 22                 NaN                               NaN
# 23                 NaN                               NaN

# %%
alt.Chart(dat).mark_bar().encode(
    x='Geographical Region',
    y='Capacity (MW) 2013',
    color='Country')
