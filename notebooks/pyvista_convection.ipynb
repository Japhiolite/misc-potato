# %%
# %matplotlib inline
from pyvista import set_plot_theme
set_plot_theme('document')
import matplotlib.pyplot as plt
import pyvista as pv
import numpy as np

# %%
mesh = pv.read('../../../Soultz2D_ini_final.vtk')

# %%
mesh.plot(show_edges=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FAD68290F98>

# %%
plotter = pv.Plotter()  # instantiate the plotter
plotter.add_mesh(mesh)    # add a dataset to the scene
cpos = plotter.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FAA50ABAEB8>

# %%
from pyvista import examples

# %%
bun = examples.download_bunny_coarse()

# %%
bun.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FAD81606DD8>

# %%
import pyvista as pv
from pyvista import examples

#dataset = examples.load_hexbeam()
dataset = pv.read('../../../Perth_transient_final.vtk')

# Use the slicer tool
tool = pv.OrthogonalSlicer(dataset)

# Get the plotter for adding more datasets:
p = tool.plotter
p.show_grid()
# Out:
# interactive(children=(FloatSlider(value=2525.0, continuous_update=False, description='x', max=4775.0, min=275.…
